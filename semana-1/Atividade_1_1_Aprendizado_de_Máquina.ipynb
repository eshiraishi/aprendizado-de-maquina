# %% [markdown]
# ## Parte 1: Exercícios Teóricos
#
# Na maior parte das atividades teremos 2 partes:
#
# - Uma com exercícios teóricos, envolvendo as questões conceituas de algorimos e simulações manuais.
#
#   - Estes exercícios são baseados no livro "Introduction to Statistical Learning" e devem ser realizados após a leitura do capítulo correspondente.
#
# - Outra contendo exercícios práticos, com códigos em Python
#
#   - Devem ser feitos após realizar as atividades e leituras propostas nas aulas.
#
# ---
#
# ***IMPORTANTE:*** Para entregar a tarefa, vocês deverão fazer o download do arquivo .ipynb clicando em Arquivo $→$ Fazer Download, e enviar o arquivo baixado usando o Moodle.
#
# ---

# %% [markdown]
# ### Exercício 1.1 - [2 pontos]
#
# Para cada exemplo abaixo, indique se o problema é:
#
# i. predição ou inferência
#
# ii. regressão, classificação, ou agrupamento
#
# iii. supervisionado ou não-supervisionado
#
# iv. quais os valores de `n` (número de exemplos) e `p` (número de atributos)
#
# Justifique cada resposta.

# %% [markdown]
# a) Coletamos os dados de 1000 empresas e, para cada uma delas, coletamos dados de receita, lucro, número de empregados, indústria, crescimento e salário do presidente.
#
# Queremos criar um modelo para obter mais informações sobre quais dos fatores coletados influenciam o salário do presidente.

# %% [markdown]
# **Resposta:**
#
# *i.* Inferência, já que o objetivo é obter informações sobre os fatores que influenciam os salários.
#
# *ii.* Regressão, já que o objetivo é obter um modelo que prediz uma informação contínua (salários).
#
# *iii.* Supervisionado, já que a relação entre os dados é pré-determinada.
#
# *iv.* n = 1000 empresas e p = 5 (dados de receita, lucro, número de empregados, indústria, crescimento).

# %% [markdown]
# b) Uma empresa quer lançar um novo produto e deseja saber se o produto será um sucesso ou não.
#
# Eles coletaram dados de 20 produtos similares que foram lançados anteriormente, coletando se ele foi um sucesso ou fracasso, o preço cobrado, gasto com propaganda, preço dos concorrentes e outras 10 variáveis.

# %% [markdown]
# **Resposta:**
#
# *i.* Predição, já que o objetivo é predizer se um novo produto será um sucesso ou não.
#
# *ii.* Classificação, já que o objetivo é obter um modelo que prediz um valor categórico (se o produto será um sucesso ou não).
#
# *iii.* Supervisionado, já que a relação entre os dados é pré-determinada.
#
# *iv.* n = 20 empresas e p = 13 (o preço cobrado, gasto com propaganda, preço dos concorrentes e outras 10 variáveis).

# %% [markdown]
# c) Queremos identificar se um paciente está propenso a ter problemas cardiovasculares a partir de um grupo de indicadores de risco.
#
# Coletamos os dados de 1000 pacientes, com a informação se eles tiveram ou não problemas cardiovasculares, e com os seguintes indicadores:
# - Idade
# - Altura
# - Peso
# - Sexo
# - Triglicerídeos
# - Pressão arterial (máximo)
# - Pressão arterial (mínimo)
# - Colesterol
# - Nível de atividade física
# - Frequência de uso de tabaco
# - Frequência de abuso de bebidas álcoolicas

# %% [markdown]
# **Resposta:**
#
# *i.* Predição, já que o objetivo é obter um modelo que prediz se um paciente está propenso a ter problemas cardiovasculares ou não.
#
# *ii.* Classificação, já que o objetivo é obter um modelo que prediz um valor categórico (se o paciente está propenso ou não).
#
# *iii.* Supervisionado, já que a relação entre os dados é pré-determinada.
#
# *iv.* n = 1000 pacientes e p = 11 indicadores.

# %% [markdown]
# d) Uma rede de supermecados deseja identificar diferentes perfis de consumidores para realizar uma campanha comercial. Para tal, ela possui os seguintes dados de 10.000 consumidores, obtidos por meio de seu programa de recompensas:
#
# - Idade
# - Sexo
# - Frequência de Compras em lojas físicas
# - Frequência de Compras na loja virtual
# - Valor Médio das compras
# - Frequencia de Compras em cada uma de 10 categorias de itens
# - Gasto Médio em cada uma de 10 categorias de itens

# %% [markdown]
# **Resposta:**
#
# *i.* Inferência, já que o objetivo é identificar diferentes perfis de consumidores.
#
# *ii.* Agrupamento, já que o objetivo é identificar perfis, ou seja, colocar os dados em grupos.
#
# *iii.* Não supervisionado, já que o objetivo é identificar as relações estatísticas presentes nos dados, que a primeiro momento são desconhecidas.
#
# *iv.* n = 10000 consumidores e p = 25 atributos (Idade, Sexo, Frequência de Compras em lojas físicas, Frequência de Compras na loja virtual, Valor Médio das compras, Frequencia de Compras em cada uma de 10 categorias de itens, Gasto Médio em cada uma de 10 categorias de itens)

# %% [markdown]
# ---
# ### Exercício 1.2 - [3 pontos]
#
# Trabalharemos agora com exemplos do mundo real. A ideia é que você pense em aplicações de aprendizado de máquina.

# %% [markdown]
# a) Descreva três aplicações da vida real onde a classificação pode ser útil. Na resposta, indique quais são os preditores e se o objetivo é realiza inferência ou predição.

# %% [markdown]
# **Resposta:**
#
# 1. Diagnóstico automatizado de doenças usando informações sobre um paciente em um trabalho de predição, onde o intuito é gerar um modelo ajustado que faça o diagnóstico do paciente de forma binária (está doente / não está doente).
#
# 2. Predição de risco de crédito para clientes de uma instituição financeira, onde dadas as informações sobre clientes, os empréstimos feitos e se o cliente conseguiu pagar o empréstimo ou não, determinar se um novo cliente poderá arcar com o empréstimo proposto ou não.
#
# 3. Identificação de rostos em imagens de câmeras em um trabalho de predição, onde dada uma imagem, o modelo identificará se um rosto está presente ou não.

# %% [markdown]
# b) Descreva três aplicações da vida real onde a *regressão* pode ser útil. Na resposta, indique quais são os preditores e se o objetivo é realiza inferência ou predição.

# %% [markdown]
# **Resposta:**
#
# 1. Previsão de crescimento de ações, onde dadas as informações de uma empresa e seu histórico de preço no mercado de ações, predizer seu valor no futuro.
#
# 2. Predição de trânsito / fluxo de automóveis em um determinado local e tempo, dado o histórico de rotas ou passagens por um determinado trecho.
#
# 3. Predição de colheita / safra de produtos agrícolas dado o histórico geográfico e informações sobre o tipo de planta cultivado naquele período.

# %% [markdown]
# c) Descreva três aplicações da vida real onde análise for agrupamento pode ser útil. Indique quais os preditores em cada caso.

# %% [markdown]
# **Resposta:**
#
# 1. Um trabalho de inferência onde usando os histórico de compras e cadastro de diversos clientes de uma loja de varejo, usar agrupamento para relacionar diversos tipos de clientes a partir dos produtos comprados em comum e traçar perfis em comum a partir das informações desses clientes.
#
# 2. Um trabaho de inferência onde os genes de diversos indivíduos são agrupados e os genes em comum dos indivíduos de cada grupo são relacionados a características desses indivíduos, como fenótipos, doenças, propensões, etc.
#
# 3. Um modelo de predição que faz agrupamento de documentos jurídicos, onde dado um documento, seu conteúdo é analisado e o grupo de documentos a qual ele pertence é indicado.

# %% [markdown]
# ---
# ### Exercício 1.3 - [1 ponto]
#
# Veremos agora sobre modos de avaliar o desempenho de um modelo. Suponha que você treinou um modelo de regressão e um de classificação sobre um conjunto de dados de treino. Ao realizar os testes, obteve os seguintes resultados, onde Y é o valor alvo, e Modelo é a saída do seu modelo:
#
# Regressão:
#
# Observação |  Y (alvo)  | Saída do Modelo
# -----------|------------|-------------------
# 1          |   3.0     | 4.0
# 2          |   5.0     | 7.0
# 3          |   1.0     | 4.0
# 4          |   -2.0    | -5.0
# 5          |   10.0    | 5.0
#
# Classificação:
#
# Observação |  Y (alvo)  | Saída do Modelo
# -----------| -------|-------------------
# 1          |   azul     | vermelho
# 2          |   azul     | azul
# 3          |   vermelho | azul
# 4          |   azul     | azul
# 5          |   vermelho | vermelho

# %% [markdown]
# a) Qual o erro (MSE) do modelo no caso da regressão para cada entrada?
#
# Indique quais as contas realizadas. Exemplo: $\sqrt{2^2 + 3^2} = 4$

# %% [markdown]
# ### **Resposta:**
# $$
#     MSE = \sqrt{
#         (3.0     - 4.0)^2 +
#         (5.0     - 7.0)^2 +
#         (1.0     - 4.0)^2 +
#         (-2.0    + 5.0)^2 +
#         (10.0    - 5.0)^2
#     } \\
#     MSE = \frac{\sqrt{(1)^2 + (-2)^2 + (-3)^2 + (3)^2 + (5)^2}} 5 \\
#     MSE = \frac{\sqrt{1 + 4 + 9 + 9 + 25}} 5 \\
#     MSE = \frac{\sqrt{48}} 5 \approx 1,38
# $$

# %% [markdown]
# b) Qual o erro (Taxa de acerto) do modelo no caso da classificação para cada entrada?
#
# Indique quais as contas realizadas.

# %% [markdown]
# **Resposta:**

# %% [markdown]
# $$
#     Ac = \frac{
#          (\text{azul}     == \text{vermelho}) +
#          (\text{azul}     == \text{azul}) +
#          (\text{vermelho} == \text{azul}) +
#          (\text{azul}     == \text{azul}) +
#          (\text{vermelho} == \text{vermelho})}{5}
#     \\ Ac = \frac{0 + 1 + 0 + 1 + 1}{5} = \frac 3 5 = 0,6 = 60\%
# $$

# %% [markdown]
# ---
# ## Parte 2: Exercícios Práticos com Python

# %% [markdown]
# ### Exercício 2.1 - [2 pontos]
# Baixe o conjunto de dados `sklearn.datasets.fetch_california_housing` do scikit-learn, no formato **Pandas**, conforme exemplo visto em aula.
#
# https://scikit-learn.org/stable/datasets/real_world.html
#
# --
#
# Em seguida, gere 8 histogramas, um para cada atributo, colocando-os em uma grade de 2 linhas 4 colunas. Utilize o comando `plt.subplot`.
#
# Escolha um número de bins adequado para cada gráfico, de modo a permitir uma boa visualização dos dados. Não esqueça também de indicar o conteúdo de cada eixo de cada gráfico.
#
# --
#
# No link abaixo o autor colocou exemplos de como utilizar o comando `plt.subplot`:
#
# https://www.geeksforgeeks.org/multiplots-in-python-using-matplotlib/

# %%
from sklearn.datasets import fetch_california_housing

# %%
X, y = california_housings = fetch_california_housing(as_frame = True, return_X_y=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(30, 10))
for index, column in enumerate(X.columns):
    plt.subplot(2, 4, index+1)
    plt.hist(X[column])
    plt.xlabel(column)
    plt.ylabel('Contagem')
    plt.title(f'{column} x Contagem')

# %% [markdown]
# ### Exercício 2.2 - [2 pontos]
#
# Como o mesmo conjunto de dados, gere agora os gráficos de dispersão para as 8 categorias. Organize-os de forma similar aos do item 2.1.

# %%
plt.figure(figsize=(30,10))
for index, column in enumerate(df.columns):
    plt.subplot(2, 4, index+1)
    plt.scatter(df[column], y)
    plt.xlabel(column)
    plt.ylabel('Preço da casa')
    plt.title(f'{column} x Preço das casas')

# %% [markdown]
# A partir dos gráficos gerados, quais dos atributos parecem possuir uma correlação com o preço das casas? Justifique sua resposta.

# %% [markdown]
# **Resposta:**

# %% [markdown]
# Isoladamente, o único atributo que parece possuir uma correlação com o preço das casas é `MedInc`, porque aumenta proporcionalmente ao preço das casas. `HouseAge, Population, Latitude, Longitude` são valores muito dispersos para identificar a partir da dispersão sua relação com o preço das casas e `AveRooms, AveBedrms, Population` são menos dispersos mas possuem uma distribuição muito baixa nos seus histogramas para avaliar sua correlação a partir da dispersão.
